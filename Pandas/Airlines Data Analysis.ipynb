# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
data = pd.read_csv("../Excel/airlines.csv", encoding = "latin1")
data.head()
# Out:
#    Ref      id  Gender Satisfied  Age  Age Band   Type of Travel     Class  \
# 0    0   70172    Male         Y   13  Under 18  Personal Travel  Eco Plus
# 1    1    5047    Male         N   25  25 to 34  Business travel  Business
# 2    2  110028  Female         Y   26  25 to 34  Business travel  Business
# 3    3   24026  Female         Y   25  25 to 34  Business travel  Business
# 4    4  119299    Male         Y   61  55 to 64  Business travel  Business
#
#    Flight Distance          Destination  ... Seat comfort  \
# 0             4760                India  ...            5
# 1              235  Republic of Ireland  ...            1
# 2             4760                India  ...            5
# 3              560               Norway  ...            2
# 4             4760                India  ...            5
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       5                 4                 3
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# Ref                                    0
# id                                     0
# Gender                                 0
# Satisfied                              0
# Age                                    0
# Age Band                               0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Destination                            0
# Continent                              0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# ...

# %%
data["Arrival Delay in Minutes"].fillna(data["Arrival Delay in Minutes"].mean(), inplace = True)
data.isna().sum()
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_3548\2621643070.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Arrival Delay in Minutes"].fillna(data["Arrival Delay in Minutes"].mean(), inplace = True)
# Ref                                  0
# id                                   0
# Gender                               0
# Satisfied                            0
# Age                                  0
# Age Band                             0
# Type of Travel                       0
# ...

# %%
sns.set_theme(rc={'figure.figsize':(8,6)})
sns.barplot(data[data["Seat comfort"] < 4]["Age Band"].value_counts(), palette = ["Red", "Blue", "Orange", "Pink", "Purple", "Brown", "Yellow", "Green", "Magenta", "Gold", "Silver", "Cyan", "Seagreen", "Teal"], saturation = 1.0).set_ylim(2000, 10500)
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_3548\1904010761.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data[data["Seat comfort"] < 4]["Age Band"].value_counts(), palette = ["Red", "Blue", "Orange", "Pink", "Purple", "Brown", "Yellow", "Green", "Magenta", "Gold", "Silver", "Cyan", "Seagreen", "Teal"], saturation = 1.0).set_ylim(2000, 10500)
# C:\Users\muham\AppData\Local\Temp\ipykernel_3548\1904010761.py:2: UserWarning: The palette list has more values (14) than needed (7), which may not be intended.
#   sns.barplot(data[data["Seat comfort"] < 4]["Age Band"].value_counts(), palette = ["Red", "Blue", "Orange", "Pink", "Purple", "Brown", "Yellow", "Green", "Magenta", "Gold", "Silver", "Cyan", "Seagreen", "Teal"], saturation = 1.0).set_ylim(2000, 10500)
# (2000.0, 10500.0)

# %%
sns.set_theme(rc={'figure.figsize':(8,6)})
sns.barplot(data[data["Inflight entertainment"] < 4]["Age Band"].value_counts(), palette = ["Red", "Blue", "Orange", "Pink", "Purple", "Brown", "Yellow", "Green", "Magenta", "Gold", "Silver", "Cyan", "Seagreen", "Teal"], saturation = 1.0).set_ylim(2000, 10500)
# Out:
# C:\Users\muham\AppData\Local\Temp\ipykernel_3548\665503006.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data[data["Inflight entertainment"] < 4]["Age Band"].value_counts(), palette = ["Red", "Blue", "Orange", "Pink", "Purple", "Brown", "Yellow", "Green", "Magenta", "Gold", "Silver", "Cyan", "Seagreen", "Teal"], saturation = 1.0).set_ylim(2000, 10500)
# C:\Users\muham\AppData\Local\Temp\ipykernel_3548\665503006.py:2: UserWarning: The palette list has more values (14) than needed (7), which may not be intended.
#   sns.barplot(data[data["Inflight entertainment"] < 4]["Age Band"].value_counts(), palette = ["Red", "Blue", "Orange", "Pink", "Purple", "Brown", "Yellow", "Green", "Magenta", "Gold", "Silver", "Cyan", "Seagreen", "Teal"], saturation = 1.0).set_ylim(2000, 10500)
# (2000.0, 10500.0)

# %%
sns.set_theme(rc={'figure.figsize':(8,6)})
sns.barplot(data[data["Inflight entertainment"] < 4]["Age Band"].value_counts(), palette = ["Red", "Blue", "Orange", "Pink", "Purple", "Brown", "Yellow", "Green", "Magenta", "Gold", "Silver", "Cyan", "Seagreen", "Teal"], saturation = 1.0).set_ylim(2000, 10500)
# Out:
# Age Band
# 25 to 34      10097
# 35 to 44       9776
# 45 to 54       6939
# 18 to 24       6778
# 55 to 64       5003
# Under 18       4786
# 65 or over     2933
# Name: count, dtype: int64

# %%
sns.set_theme(rc={'figure.figsize':(8,6)})
sns.barplot(data[data["Inflight entertainment"] < 4]["Age Band"].value_counts(), palette = ["Red", "Blue", "Orange", "Pink", "Purple", "Brown", "Yellow", "Green", "Magenta", "Gold", "Silver", "Cyan", "Seagreen", "Teal"], saturation = 1.0).set_ylim(2000, 10500)
# Out:
# Age Band
# 25 to 34      10097
# 35 to 44       9776
# 45 to 54       6939
# 18 to 24       6778
# 55 to 64       5003
# Under 18       4786
# 65 or over     2933
# Name: count, dtype: int64

# %%
# Out:
# dtype('int64')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example data: categories and counts
data1 = {
    'Issue': data[data["Inflight entertainment"] < 4]["Age Band"].value_counts().index,
    'Total': data[data["Inflight entertainment"] < 4]["Age Band"].value_counts().values
}

df = pd.DataFrame(data1)
df = df.sort_values(by='Total', ascending=False)  # Sort descending

# Calculate cumulative percentage
df['Cumulative %'] = df['Total'].cumsum() / df['Total'].sum() * 100

# Create bar chart for count
fig, ax1 = plt.subplots(figsize=(10, 6))
ax1.bar(df['Issue'], df['Total'], color='skyblue')

# Create line chart for cumulative %
ax2 = ax1.twinx()
ax2.plot(df['Issue'], df['Cumulative %'], color='red', marker='o', linestyle='-', linewidth=2)
ax2.set_ylabel('Cumulative Percentage')

# Plot settings
plt.title('Pareto Chart of Customer Issues')
plt.grid(axis='y', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data[data["Inflight entertainment"] < 4]["Age Band"].value_counts().index
# Out:
# Index(['35 to 44', '25 to 34', '45 to 54', '18 to 24', '55 to 64', 'Under 18',
#        '65 or over'],
#       dtype='object', name='Age Band')
